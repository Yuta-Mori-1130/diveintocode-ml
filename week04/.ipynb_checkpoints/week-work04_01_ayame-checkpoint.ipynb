# %% [markdown]
# [課題のURL](https://diver.diveintocode.jp/curriculums/1633)

# %% [markdown]
# # Week4授業前課題1 アヤメの分類

# %% [markdown]
# #  【課題1】練習のために特徴量とカテゴリを選択

# %% [markdown]
# * irisデータセットをWeek3同様に取得した後、データフレームからこれらを抜き出してください。
#
# virgicolorとvirginica
# sepal_lengthとpetal_length

# %%
import numpy as np
import pandas as pd
import seaborn
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.datasets import load_iris

# %% [markdown]
# [データセット](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_iris.html)

# %% [markdown]
# sepal:がく
# petal:花弁

# %%
# データの読み込み

data_iris = load_iris()

X = pd.DataFrame(data_iris.data, columns=["sepal_length","sepal_width","petal_length","petal_width"])
#X.head(5)

y = pd.DataFrame(data_iris.target, columns=["Species"])
#y.head(5)

df = pd.concat([X, y], axis=1)
df.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  Species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %%
# データフレームからこれらを抜き出してください。
# virgicolorとvirginica
# sepal_lengthとpetal_length
# 参考情報:setosa:0, virgiclor:1, virginica:2

# virgicolorとvirginicaを抜き出す。
df_temp1 = df[ df["Species"] == 1 ]
df_temp2 = df[ df["Species"] == 2 ]
df_temp3 = pd.concat([df_temp1, df_temp2], axis=0)

# sepal_lengthとpetal_lengthを抜き出し結合する
df2 = df_temp3[["sepal_length", "petal_length", "Species"]]
#print(df2)
print(df2.head(5))
print(df2.tail(5))
# Out:
#     sepal_length  petal_length  Species
# 50           7.0           4.7        1
# 51           6.4           4.5        1
# 52           6.9           4.9        1
# 53           5.5           4.0        1
# 54           6.5           4.6        1
#      sepal_length  petal_length  Species
# 145           6.7           5.2        2
# 146           6.3           5.0        2
# 147           6.5           5.2        2
# 148           6.2           5.4        2
# 149           5.9           5.1        2

# %% [markdown]
# # 【問題2】データの分析

# %% [markdown]
# 抜き出したデータの
#  * 散布図
#  * 箱ひげ図（boxplot）
#  * バイオリン図（violinplot）
#
#  を表示してください。

# %%
# 散布図の描画

# データ準備
x1 = df2[df2["Species"] == 1]["sepal_length"]
y1 = df2[df2["Species"] == 1]["petal_length"]
x2 = df2[df2["Species"] == 2]["sepal_length"]
y2 = df2[df2["Species"] == 2]["petal_length"]

# グラフの描画
plt.title("scatter", fontsize=20) # (5)タイトル
plt.xlabel("sepal_length", fontsize=20) # (6)x軸ラベル
plt.ylabel("petal_length", fontsize=20) # (7)y軸ラベル

plt.scatter(x1, y1, s=10, c="g", marker="D", label="virgiclor(1)") #(10)散布図の描画
plt.scatter(x2, y2, s=10, c="b", marker="D", label="virginica(2)") #(10)散布図の描画

plt.legend(bbox_to_anchor=(0, 0), loc='upper right', borderaxespad=0, fontsize=10)
plt.show()

# %%
# 箱ひげ図の描画

data1= df2[ df2["Species"] == 1 ]
data2 = df2[ df2["Species"] == 2 ]

for column_name in df2:
    print(column_name)
    if column_name == "Species":
        # 最終列(ラベル)は表示しない。
        break
    
    data = (data1[column_name], data2[column_name])

    fig, axes = plt.subplots(figsize = (12, 8))
    plt.boxplot(data, patch_artist=True, widths=0.2,boxprops=dict(facecolor='skyblue',
                             color='black', linewidth=1))
    axes.set_xticklabels(['virgiclor', "virginica"])
    plt.ylabel(column_name)
    plt.show()
# Out:
# sepal_length
# petal_length
# Species

# %%
# バイオリン図の描画
import seaborn as sns

for column_name in df2:
    #print(column_name)
    if column_name == "Species":
        # 最終列(ラベル)は表示しない。
        break

    plt.style.use('default')
    sns.set()
    sns.set_style('whitegrid')
    sns.set_palette('gray')

    fig = plt.figure()
    ax = fig.add_subplot(1, 1, 1)

    ax.violinplot([data1[column_name], data2[column_name]])
    ax.set_xticks([1, 2])
    ax.set_xticklabels(["virgiclor", "virginica"])
    ax.set_ylabel(column_name)

    plt.show()

# %% [markdown]
# # 【問題3】前処理・訓練データと検証データの分割

# %% [markdown]
# * 訓練データと検証データの分割を行います。
# 訓練データ75%、検証データ25%として分割してください。

# %%
from sklearn.model_selection import train_test_split

# 特徴量（説明変数）をX、正解（目的変数）をyというndarrayに格納
X = df2[["sepal_length", "petal_length"]].values
#print(X)
#print(type(X))

y = df2[["Species"]].values
#print(y)
#print(type(y))

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=1)
#print(X_train)
#print(y_train.shape)
#print(y_train)
#print(X_test)

# %%
#print(len(X_train)) # 75, 訓練データ
#print(len(X_test)) # 25, 検証データ
#print(len(y_train)) # 75
#print(len(y_test)) # 25
# Out:
# 75

# %% [markdown]
# # 【問題4】前処理・標準化

# %% [markdown]
# * 分類精度をあげるための加工を行います。手法ごとに適切な方法は異なりますが、ここでは一例として 標準化 を行うことにします。

# %%
# 標準化は訓練用のデータでfitを実施
# 訓練用、検証用双方のデータにtransformを行います

# 良く使うメソッドは次の3つ。
# fit(X)
# 配列Xの平均と分散を計算して、記憶する（変換は行わない）。

#transform(X)
#配列Xに変換を施して、変換後の配列を返す。

#fit_transform(X)
#配列Xに対して、fitとtransformを同時に行う。

#なお、2次元配列を変換する場合、縦 (axis=0) 方向に変換が行われる。

# %%
from sklearn.preprocessing import StandardScaler

print("標準化前")
print(X_train.mean(axis=0))
print(X_train.std(axis=0))

scaler = StandardScaler()
scaler.fit(X_train)
X_train_std = scaler.transform(X_train)

print("標準化後")
print(X_train_std.mean(axis=0))
print(X_train_std.std(axis=0))

X_test_std = scaler.transform(X_test)
# Out:
# 標準化前
# [6.28266667 4.892     ]
# [0.64278007 0.83294818]
# 標準化後
# [1.50472227e-15 6.06921920e-16]
# [1. 1.]

# %% [markdown]
# # 【問題5】学習と推定

# %%
# 最近傍法（k-nearest neighbors, k-nn）で学習
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

#print(y_train.shape)
#print(y_train.reshape(75,))

for i in range(1, 6):
    #print(i)
    knn = KNeighborsClassifier(n_neighbors=i) # インスタンス生成。n_neighbors:Kの数
    knn.fit(X_train_std, y_train.reshape(75,)) # モデル作成実行
    y_pred = knn.predict(X_test_std) # 予測実行
    print(y_pred)
    #print(i,"-nn", " = ",accuracy_score(y_test, y_pred))
# Out:
# [2 2 2 2 2 1 1 2 2 2 2 1 1 2 2 1 1 1 2 1 1 1 2 2 1]
# [2 2 2 2 2 1 1 2 2 2 2 1 1 2 2 1 1 1 2 1 1 1 2 2 1]
# [2 2 2 2 2 1 1 2 2 2 2 1 1 2 2 1 1 1 2 1 1 2 2 2 1]
# [2 2 2 2 2 1 1 2 2 2 2 1 1 2 2 1 1 1 2 1 1 2 2 2 1]
# [2 2 2 2 2 1 1 2 2 2 2 1 1 2 2 1 1 1 2 1 1 2 2 2 1]

# %% [markdown]
# # 【問題6】評価

# %% [markdown]
# * scikit-learnを使い4種類( Accuracy（正解率）、Precision（適合率）、Recall（再現率）、F値)の指標を計算する

# %%
print("Accuracy（正解率）")

for i in range(1, 6):
    #print(i)
    knn = KNeighborsClassifier(n_neighbors=i) # インスタンス生成。n_neighbors:Kの数
    knn.fit(X_train_std, y_train.reshape(75,)) # モデル作成実行
    y_pred = knn.predict(X_test_std) # 予測実行
    print(i,"-nn", " = ",accuracy_score(y_test, y_pred))

# 問8用の表示用にデフォルト5-nnのデータを保存
list_score_KN = []
list_score_KN.append(accuracy_score(y_test, y_pred))
# Out:
# Accuracy（正解率）
# 1 -nn  =  0.88
# 2 -nn  =  0.88
# 3 -nn  =  0.92
# 4 -nn  =  0.92
# 5 -nn  =  0.92

# %%
print("Precision（適合率）")

for i in range(1, 6):
    #print(i)
    knn = KNeighborsClassifier(n_neighbors=i) # インスタンス生成。n_neighbors:Kの数
    knn.fit(X_train_std, y_train.reshape(75,)) # モデル作成実行
    y_pred = knn.predict(X_test_std) # 予測実行
    print(i,"-nn", " = ",precision_score(y_test, y_pred))

# 問8用の表示用にデフォルト5-nnのデータを保存
list_score_KN.append(precision_score(y_test, y_pred))
# Out:
# Precision（適合率）
# 1 -nn  =  0.8181818181818182
# 2 -nn  =  0.8181818181818182
# 3 -nn  =  0.9
# 4 -nn  =  0.9
# 5 -nn  =  0.9

# %%
print("Recall（再現率）")

for i in range(1, 6):
    #print(i)
    knn = KNeighborsClassifier(n_neighbors=i) # インスタンス生成。n_neighbors:Kの数
    knn.fit(X_train_std, y_train.reshape(75,)) # モデル作成実行
    y_pred = knn.predict(X_test_std) # 予測実行
    print(i,"-nn", " = ",recall_score(y_test, y_pred))

# 問8用の表示用にデフォルト5-nnのデータを保存
list_score_KN.append(recall_score(y_test, y_pred))
# Out:
# Recall（再現率）
# 1 -nn  =  0.9
# 2 -nn  =  0.9
# 3 -nn  =  0.9
# 4 -nn  =  0.9
# 5 -nn  =  0.9

# %%
print("F値")

for i in range(1, 6):
    #print(i)
    knn = KNeighborsClassifier(n_neighbors=i) # インスタンス生成。n_neighbors:Kの数
    knn.fit(X_train_std, y_train.reshape(75,)) # モデル作成実行
    y_pred = knn.predict(X_test_std) # 予測実行
    print(i,"-nn", " = ",f1_score(y_test, y_pred))
    
# 問8用の表示用にデフォルト5-nnのデータを保存
list_score_KN.append(f1_score(y_test, y_pred))
# Out:
# F値
# 1 -nn  =  0.8571428571428572
# 2 -nn  =  0.8571428571428572
# 3 -nn  =  0.9
# 4 -nn  =  0.9
# 5 -nn  =  0.9

# %%
#print(list_score_KN)
# Out:
# [0.92, 0.9, 0.9, 0.9]

# %% [markdown]
# * 混同行列をscikit-learnを使い表示する

# %%
print("混同行列")

for i in range(1, 6):
    #print(i)
    knn = KNeighborsClassifier(n_neighbors=i) # インスタンス生成。n_neighbors:Kの数
    knn.fit(X_train_std, y_train.reshape(75,)) # モデル作成実行
    y_pred = knn.predict(X_test_std) # 予測実行
    print(i,"-nn", " = ")
    print(confusion_matrix(y_test, y_pred))
# Out:
# 混同行列
# 1 -nn  =
# [[ 9  1]
#  [ 2 13]]
# 2 -nn  =
# [[ 9  1]
#  [ 2 13]]
# 3 -nn  =
# [[ 9  1]
#  [ 1 14]]
# 4 -nn  =
# [[ 9  1]
#  [ 1 14]]
# 5 -nn  =
# [[ 9  1]
#  [ 1 14]]

# %% [markdown]
# * 4種類の指標値の意味について簡単に調査して文章でまとめる

# %% [markdown]
# Accuracy（正解率）:正や負と予測したデータのうち，実際にそうであるものの割合
# Precision（適合率）:正と予測したデータのうち，実際に正であるものの割合
# Recall（再現率）:実際に正であるもののうち，正であると予測されたものの割合
# F値:再現率と適合率の調和平均．
#
# TP(True Positive):正しいものを正しく推測できたもの
# TN(True Negative):正しくないものを正しく推測できたもの
# FN(False Negaitve):正しいものを誤って正しいと推測したもの
# FP(False Positive):正しくないものを誤って正しいと推測したもの
#
# 混合行列 =
# [TP, FN]
# [FP, TN]

# %% [markdown]
# # 【問題7】可視化

# %%
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import matplotlib.patches as mpatches
def decision_region(X, y, model, step=0.01, title='decision region', xlabel='xlabel', ylabel='ylabel', target_names=['versicolor', 'virginica']):
    """
    2値分類を2次元の特徴量で学習したモデルの決定領域を描く。
    背景の色が学習したモデルによる推定値から描画される。
    散布図の点は訓練データまたは検証データである。

    Parameters
    ----------------
    X : ndarray, shape(n_samples, 2)
        特徴量
    y : ndarray, shape(n_samples,)
        ラベル
    model : object
        学習したモデルのインスンタスを入れる
    step : float, (default : 0.1)
        推定値を計算する間隔を設定する
    title : str
        グラフのタイトルの文章を与える
    xlabel, ylabel : str
        軸ラベルの文章を与える
    target_names= : list of str
        凡例の一覧を与える
    """
    # setting
    scatter_color = ['red', 'blue']
    contourf_color = ['pink', 'skyblue']
    n_class = 2
    # pred
    mesh_f0, mesh_f1  = np.meshgrid(np.arange(np.min(X[:,0])-0.5, np.max(X[:,0])+0.5, step), np.arange(np.min(X[:,1])-0.5, np.max(X[:,1])+0.5, step))
    mesh = np.c_[np.ravel(mesh_f0),np.ravel(mesh_f1)]
    y_pred = model.predict(mesh).reshape(mesh_f0.shape)
    # plot
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.contourf(mesh_f0, mesh_f1, y_pred, n_class-1, cmap=ListedColormap(contourf_color))
    plt.contour(mesh_f0, mesh_f1, y_pred, n_class-1, colors='y', linewidths=3, alpha=0.5)
    for i, target in enumerate(set(y)):
        plt.scatter(X[y==target][:, 0], X[y==target][:, 1], s=80, color=scatter_color[i], label=target_names[i], marker='o')
    patches = [mpatches.Patch(color=scatter_color[i], label=target_names[i]) for i in range(n_class)]
    plt.legend(handles=patches)
    plt.legend()
    plt.show()

# %%
knn = KNeighborsClassifier(n_neighbors=5) # インスタンス生成。n_neighbors:Kの数
knn.fit(X_train_std, y_train.reshape(75,))

decision_region(X_train_std, y_train.reshape(75,), knn, step=0.01, title='decision region of 5-nn', xlabel='sepal_length', ylabel='petal_length', target_names=['versicolor', 'virginica'])

# %% [markdown]
# # 【問題8】他の手法の学習

# %% [markdown]
# * 以下の全ての手法について学習・推定・評価・可視化を行ってください。

# %% [markdown]
# - 最近傍法
# - ロジスティック回帰
# - SVM
# - 決定木
# - ランダムフォレスト

# %%
# 最近傍法は5-nnを"【問題5】学習と推定"と"【問題6】評価"と"【問題7】可視化"で実施

# %%
# ロジスティック回帰

from sklearn.linear_model import LogisticRegression

# モデルの生成
clf = LogisticRegression(random_state=0).fit(X_train_std, y_train.reshape(75,))
y_pred = clf.predict(X_test_std)

print("Accuracy（正解率）", accuracy_score(y_test, y_pred))
print("Precision（適合率）", precision_score(y_test, y_pred))
print("Recall（再現率）", recall_score(y_test, y_pred))
print("F値",f1_score(y_test, y_pred))

list_score_logistic = [accuracy_score(y_test, y_pred), precision_score(y_test, y_pred), recall_score(y_test, y_pred), f1_score(y_test, y_pred) ]
#print(list_score_logistic)
# Out:
# Accuracy（正解率） 0.88
# Precision（適合率） 0.8181818181818182
# Recall（再現率） 0.9
# F値 0.8571428571428572

# %%
# ロジスティック回帰の可視化

decision_region(X_train_std, y_train.reshape(75,), clf, step=0.01, title='Logistic Regression classifier', xlabel='sepal_length', ylabel='petal_length', target_names=['versicolor', 'virginica'])

# %%
# SVM
from sklearn.svm import SVC

clf = SVC().fit(X_train_std, y_train.reshape(75,))

y_pred = clf.predict(X_test_std)

print("Accuracy（正解率）", accuracy_score(y_test, y_pred))
print("Precision（適合率）", precision_score(y_test, y_pred))
print("Recall（再現率）", recall_score(y_test, y_pred))
print("F値",f1_score(y_test, y_pred))

list_score_svc = [accuracy_score(y_test, y_pred), precision_score(y_test, y_pred), recall_score(y_test, y_pred), f1_score(y_test, y_pred) ]
#print(list_score_svc)
# Out:
# Accuracy（正解率） 0.92
# Precision（適合率） 0.9
# Recall（再現率） 0.9
# F値 0.9

# %%
# SVMの可視化

decision_region(X_train_std, y_train.reshape(75,), clf, step=0.01, title='Support Vector Classification', xlabel='sepal_length', ylabel='petal_length', target_names=['versicolor', 'virginica'])

# %%
# 決定木
from sklearn.tree import DecisionTreeClassifier

clf = DecisionTreeClassifier().fit(X_train_std, y_train.reshape(75,))
y_pred = clf.predict(X_test_std)

print("Accuracy（正解率）", accuracy_score(y_test, y_pred))
print("Precision（適合率）", precision_score(y_test, y_pred))
print("Recall（再現率）", recall_score(y_test, y_pred))
print("F値",f1_score(y_test, y_pred))

list_score_dtc = [accuracy_score(y_test, y_pred), precision_score(y_test, y_pred), recall_score(y_test, y_pred), f1_score(y_test, y_pred) ]
#print(list_score_dtc)
# Out:
# Accuracy（正解率） 0.88
# Precision（適合率） 0.8181818181818182
# Recall（再現率） 0.9
# F値 0.8571428571428572
# [0.88, 0.8181818181818182, 0.9, 0.8571428571428572]

# %%
decision_region(X_train_std, y_train.reshape(75,), clf, step=0.01, title='A decision tree classifier', xlabel='sepal_length', ylabel='petal_length', target_names=['versicolor', 'virginica'])

# %%
# ランダムフォレスト
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification

clf = RandomForestClassifier().fit(X_train_std, y_train.reshape(75,))
y_pred = clf.predict(X_test_std)

print("Accuracy（正解率）", accuracy_score(y_test, y_pred))
print("Precision（適合率）", precision_score(y_test, y_pred))
print("Recall（再現率）", recall_score(y_test, y_pred))
print("F値",f1_score(y_test, y_pred))

list_score_rfc = [accuracy_score(y_test, y_pred), precision_score(y_test, y_pred), recall_score(y_test, y_pred), f1_score(y_test, y_pred) ]
# print(list_score_rfc)
# Out:
# Accuracy（正解率） 0.88
# Precision（適合率） 0.8181818181818182
# Recall（再現率） 0.9
# F値 0.8571428571428572

# %%
decision_region(X_train_std, y_train.reshape(75,), clf, step=0.01, title='A random forest classifier', xlabel='sepal_length', ylabel='petal_length', target_names=['versicolor', 'virginica'])

# %% [markdown]
# * 指標値を１つの表にまとめてください。

# %%
list_score = [list_score_KN, list_score_logistic, list_score_svc, list_score_dtc, list_score_rfc]
index1 = ["最近傍法", "ロジスティック回帰", "SVM", "決定木", "ランダムフォレスト"]
columns1 =["Accuracy（正解率）", "Precision（適合率）", "Recall（再現率）", "F値"]
pd.DataFrame(data=list_score, index=index1, columns=columns1)
# Out:
#            Accuracy（正解率）  Precision（適合率）  Recall（再現率）        F値
# 最近傍法                0.92        0.900000          0.9  0.900000
# ロジスティック回帰           0.88        0.818182          0.9  0.857143
# SVM                 0.92        0.900000          0.9  0.900000
# 決定木                 0.88        0.818182          0.9  0.857143
# ランダムフォレスト           0.88        0.818182          0.9  0.857143

# %% [markdown]
# Accuracy（正解率）、Precision（適合率）は下記の方法が良かった。
#  最近傍法
#  SVM
# →境界線がデータの分布に応じて複雑に設定されている?
#
# 下記は、単純に設定されている。
#  ロジスティック回帰
#  決定木
#  ランダムフォレスト
