# %% [markdown]
# [課題のURL](https://diver.diveintocode.jp/curriculums/1626)

# %% [markdown]
# # Week**

# %%
import matplotlib.pyplot
import seaborn

iris = seaborn.load_dataset( "iris" )
seaborn.pairplot( iris, hue="species", palette="husl" )
matplotlib.pyplot.show()
